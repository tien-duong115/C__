# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import re

url = "https://catalog.sjsu.edu/preview_program.php?catoid=10&poid=2880&returnto=741"
data = requests.get(url).content
soup = BeautifulSoup(data, "html.parser")
job_elements = soup.find_all("td", class_="block_content_outer")
    
with open('my_data.txt','w') as file:
    for job_element in job_elements:
        file.write(job_element.text.replace('\n','-'))
        
with open('my_data.txt','rt') as file:
    data = file.read()
    print(re.sub('\-+','\n\n', data))
# Out:
# HELP
#
# MyRoadmaps Catalog
#
# Psychology, BA (2021
#
# 2022)
#
# Print Degree (opens a new window) | Print
#
# Friendly Page (opens a new window)
#
# Facebook this Page (opens a new window)
#
# Tweet this Page (opens a new window)
#
#
#
#  Return to: 4
#
# Year Roadmaps (2021
#
# 2022)The following roadmap is a sample advising map to complete the degree program in four years. Please consult your MyPlanner and major advisor  as you develop your individualized academic plan. Students must have completed 60+ units in order to enroll in SJSU Studies courses.
#
# Year 1 | Year 2 | Year 3 | Year 4
#
# Year 1Fall Semester (15 units)
#
# GE Area A1  3 unit(s)
#
# PSYC 1
#
#  Introduction to Psychology  3 unit(s) (D)
#
# GE Area A2  3 unit(s)
#
# GE Area E  3 unit(s)
#
# AFAM 2A
#
#  African Americans and the Development of America’s History and Government , AAS 33A
#
#  Asian Americans in U.S. History I , CCS 10A
#
#  Mexican Americans and the Development of U.S. History and Government , OR HIST 15
#
#  Essentials of U.S. History  3 unit(s) (D)
#
# Spring Semester (16 units)
#
# GE Area A3  ​3 unit(s)
#
# BIOL 21
#
#  Human Biology  OR BIOL 65
#
#  Human Anatomy  ​3
#
# 4 unit(s) (B2+B3)
#
# STAT 95
#
#  Elementary Statistics  ​3 unit(s) (B4)
#
# GE Area C1  3 unit(s)
#
# AFAM 2B
#
#  African Americans and the Development of America’s History and Government , AAS 33B
#
#  Asian Americans in U.S. History II , CCS 10B
#
#  Mexican Americans and the Development of U.S. History and Government , OR POLS 15
#
#  Essentials of U.S. & California Government  ​3 unit(s) (D+US123)
#
# Physical Education ​1 unit(s)
#
# Year 2Fall Semester (16 units)
#
# PSYC 30
#
#  Introductory Psychobiology  3 unit(s)
#
# GE Area B1  3 unit(s)
#
# GE Area C2  3 unit(s)
#
# PSYC 18
#
#  Introduction to Research Methods  3 unit(s)
#
# GE Area F  3 unit(s)
#
# Physical Education 1 unit(s)
#
# Writing Skills Test (WST)
#
#  Taken and Passed
#
# Spring Semester (15 units)
#
# GE Area C1 or C2  3 unit(s)
#
# PSYC 102
#
#  Psychology of Childhood , PSYC 112
#
#  Psychology of Adolescence , OR PSYC 114
#
#  Psychology of Aging  3 unit(s)
#
# PSYC 110
#
#  Adult Psychopathology  OR PSYC 142
#
#  Child Psychopathology  3 unit(s)
#
# University Elective
#
#  Lower or Upper Division 3 unit(s)
#
# University Elective
#
#  Lower or Upper Division 3 unit(s)
#
# Year 3Fall Semester (15 units)
#
# PSYC 100W
#
#  Writing Workshop  3 unit(s) (Z)
#
# PSYC 139
#
#  Psychology of Personality  OR PSYC 154
#
#  Social Psychology  3 unit(s)
#
# PSYC 129
#
#  Neuroscience , PSYC 135
#
#  Cognition , PSYC 155
#
#  Human Learning , OR PSYC 158
#
#  Perception  3 unit(s)
#
# University Elective
#
#  Lower or Upper Division 3 unit(s)
#
# University Elective
#
#  Lower or Upper Division 3 unit(s)
#
# Spring Semester (15 units)
#
# PSYC 118
#
#  Advanced Research Methods in Psychology  3 unit(s)
#
# PSYC 117
#
#  Psychological Tests and Measures  OR STAT 115
#
#  Intermediate Statistics  3 unit(s)
#
# PSYC 129
#
#  Neuroscience , PSYC 135
#
#  Cognition , PSYC 155
#
#  Human Learning , OR PSYC 158
#
#  Perception  3 unit(s)
#
# SJSU Studies Area S  3 unit(s)
#
# University Elective
#
#  Lower or Upper Division 3 unit(s)
#
# Apply to Graduate
#
# Year 4Fall Semester (14 units)
#
# Psychology Elective
#
#  Upper Division 3 unit(s)
#
# Psychology Elective
#
#  Lower or Upper Division 2 unit(s)
#
# SJSU Studies Area V  3 unit(s)
#
# University Elective
#
#  Lower or Upper Division 3 unit(s)
#
# University Elective
#
#  Lower or Upper Division 3 unit(s)
#
# Spring Semester (14 units)
#
# PSYC 190
#
#  Current Issues Capstone  OR PSYC 195
#
#  Honors Seminar in Psychology  3 unit(s)
#
# Psychology Elective
#
#  Upper Division 3 unit(s)
#
# SJSU Studies Area R  3 unit(s)
#
# University Elective
#
#  Lower or Upper Division 3 unit(s)
#
# University Elective
#
#  Lower or Upper Division 2 unit(s)
#
#
#
#  Return to: 4
#
# Year Roadmaps (2021
#
# 2022) Back to Top | Print Degree (opens a new window) | Print
#
# Friendly Page (opens a new window)
#
# Facebook this Page (opens a new window)
#
# Tweet this Page (opens a new window)
